# %%
import sys, os, time
import numpy as np

from pynq import Xlnk
from pynq import Overlay
import pynq
from multiprocessing import Process, Pipe, Queue, Event, Manager, Value, Lock

xlnk = Xlnk()
xlnk.xlnk_reset()

# %%
overlay = Overlay("./0503.bit")
# overlay?
FracNet = overlay.FracNet_0

# %%
FracNet.register_map
# Out:
# RegisterMap {
#   CTRL = Register(AP_START=0, AP_DONE=0, AP_IDLE=1, AP_READY=0, RESERVED_1=0, AUTO_RESTART=0, RESERVED_2=0),
#   GIER = Register(Enable=0, RESERVED=0),
#   IP_IER = Register(CHAN0_INT_EN=0, CHAN1_INT_EN=0, RESERVED=0),
#   IP_ISR = Register(CHAN0_INT_ST=0, CHAN1_INT_ST=0, RESERVED=0),
#   image_thermo_V = Register(image_thermo_V=0),
#   conv_weight_3x3_all_new_V = Register(conv_weight_3x3_all_new_V=0),
#   conv_weight_1x1_all_new_V = Register(conv_weight_1x1_all_new_V=0),
#   weights_all_V = Register(weights_all_V=0),
#   DDR_buf_pack_V = Register(DDR_buf_pack_V=0)
# }

# %%
bus512 = 'B,'*63 + 'B'
dt_512 = np.dtype(bus512)

bus256 = 'B,'*31 + 'B'
dt_256 = np.dtype(bus256)

print(xlnk.cma_stats())
image_thermo = xlnk.cma_array(shape=(3*224*224), dtype=np.uint32)
conv_weight_3x3_all = xlnk.cma_array(shape=(49104), dtype=dt_512)
conv_weight_1x1_all = xlnk.cma_array(shape=(6132), dtype=dt_512)
other_weight_all = xlnk.cma_array(shape=(5460), dtype=dt_512)
DDR_all = xlnk.cma_array(shape=(203400), dtype=dt_512)
# DDR_all = xlnk.cma_array(shape=(16384), dtype=dt_512)
DDR_all.shape
print(xlnk.cma_stats())
# Out:
# {'CMA Memory Available': 127725568, 'CMA Memory Usage': 0, 'Buffer Count': 0}
# {'CMA Memory Available': 110211072, 'CMA Memory Usage': 17504256, 'Buffer Count': 5}

# %%
fc_weight = np.ndarray((1000, 1024))
fc_bias = np.ndarray(1000)

# %%
image_hw_all_file = np.fromfile("image_hw_all_host_new.bin", dtype=np.uint32)
# np.copyto(image_thermo, image_hw_all_file.reshape(image_thermo.shape))

conv_weight_3x3_file = np.fromfile("conv3x3_weights_host_new.bin", dtype=dt_512)
np.copyto(conv_weight_3x3_all, conv_weight_3x3_file.reshape(conv_weight_3x3_all.shape))

conv_weight_1x1_file = np.fromfile("conv1x1_weights_host_new.bin", dtype=dt_512)
np.copyto(conv_weight_1x1_all, conv_weight_1x1_file.reshape(conv_weight_1x1_all.shape))

other_weights_file = np.fromfile("other_weights_host_new.bin", dtype=dt_512)
np.copyto(other_weight_all, other_weights_file.reshape(other_weight_all.shape))

fc_weight_file = np.fromfile("fc_weight_host.bin", dtype=np.float32)
np.copyto(fc_weight, fc_weight_file.reshape(fc_weight.shape))

fc_bias_file = np.fromfile("fc_bias_host.bin", dtype=np.float32)
np.copyto(fc_bias, fc_bias_file.reshape(fc_bias.shape))

print(DDR_all.shape)
print(len(DDR_all[0]))
print(fc_weight)
print(fc_bias)
# Out:
# (203400,)
# 64
# [[ 0.27857348 -0.90325087  0.18205236 ..., -0.46228936 -0.09374874
#    0.05890613]
#   -4.73190397e-01  -8.74734759e-01  -1.18081236e+00  -7.77666748e-01
#   -2.96712667e-01   5.31720161e-01  -2.76275039e-01  -1.58164456e-01
#   -7.04095215e-02  -1.58537674e+00  -7.72479475e-02  -7.42493391e-01
#   -3.89100239e-02  -4.49231379e-02  -4.47787568e-02  -2.57970273e-01
#   -4.54098523e-01  -4.20610279e-01  -2.53547758e-01   9.21769440e-02
#   -5.17289579e-01  -4.36340511e-01  -8.51404071e-01   4.90315765e-01
#   -1.81398764e-02  -3.42118979e-01  -1.50968298e-01  -4.06386375e-01
#   -2.27223203e-01  -3.05225328e-02   3.33691567e-01  -3.42654139e-01
#   -2.30296087e-02  -4.73861724e-01  -1.79748163e-01  -1.04607999e+00
#   -1.23648182e-01   1.25778407e-01  -4.64655995e-01  -8.60608935e-01
#   -1.01548409e+00  -3.36937815e-01   1.26717418e-01  -6.11282587e-01
#    1.37373537e-01  -2.31581643e-01   8.92701149e-02   4.82627630e-01
#    2.07970023e-01   9.46641043e-02  -1.30716228e+00   9.06970024e-01
#   -4.12485778e-01   6.74248815e-01   4.30234253e-01  -6.41292751e-01
#   -4.59696770e-01  -2.50824511e-01   9.04885307e-02  -3.45888585e-01
#   -7.84988105e-01  -7.79093385e-01  -1.80219829e+00   1.12991953e+00
#    2.61779390e-02  -5.66844523e-01  -2.31456101e-01  -6.82691753e-01
#   -7.18224049e-01  -1.55119240e+00  -6.23681068e-01  -6.68178350e-02
#    3.54575664e-01  -1.10084012e-01   8.61872554e-01   1.14760458e-01]

# %%
FracNet.register_map.image_thermo_V    = image_thermo.physical_address
FracNet.register_map.conv_weight_3x3_all_new_V   = conv_weight_3x3_all.physical_address
FracNet.register_map.conv_weight_1x1_all_new_V    = conv_weight_1x1_all.physical_address
FracNet.register_map.weights_all_V    = other_weight_all.physical_address
FracNet.register_map.DDR_buf_pack_V    = DDR_all.physical_address
FracNet.register_map
# Out:
# RegisterMap {
#   CTRL = Register(AP_START=0, AP_DONE=0, AP_IDLE=1, AP_READY=0, RESERVED_1=0, AUTO_RESTART=0, RESERVED_2=0),
#   GIER = Register(Enable=0, RESERVED=0),
#   IP_IER = Register(CHAN0_INT_EN=0, CHAN1_INT_EN=0, RESERVED=0),
#   IP_ISR = Register(CHAN0_INT_ST=0, CHAN1_INT_ST=0, RESERVED=0),
#   image_thermo_V = Register(image_thermo_V=2016411648),
#   conv_weight_3x3_all_new_V = Register(conv_weight_3x3_all_new_V=2017460224),
#   conv_weight_1x1_all_new_V = Register(conv_weight_1x1_all_new_V=2015887360),
#   weights_all_V = Register(weights_all_V=2020605952),
#   DDR_buf_pack_V = Register(DDR_buf_pack_V=2021654528)
# }

# %%
def matmul_p(weight, bias, conv_out_q):
    for i in range(1000):
        while conv_out_q.empty():
            continue
        activation = conv_out_q.get()
        logits = np.matmul(activation, weight) + bias
        p = np.argmax(logits)
#         print(p)
        predicts.append(p)
    
def avgpool(conv13):
    ret = np.ndarray((1024))
    for i in range(1024):
        ret[i] = np.sum(conv13[i])
    return ret/49

def matmul(avgpool, weight, bias):
    logits = np.matmul(avgpool, weight.T) + bias
#     print(logits.shape)
    p = np.argmax(logits)
    return p, logits

def matmul2(avgpool, weights, bias):
    logits = np.ndarray((1000))
    for i in range(1000):
        logits[i] = bias[i]
        for j in range(1024):
            logits[i] += avgpool[j]*weights[i][j]
#             print(avgpool[j]*weights[i][j])
        
    p = np.argmax(logits)
    return p, logits

def classifier(weight, bias, conv_out, num_img):
    while True:
        while conv_out.empty():
#             if i == 99999:
#                 print('AHHHHHH')
            continue
        DDR_all_p = conv_out.get()
        conv13_hw = np.ndarray((1024, 7, 7))
        for i in range(1024):
            ch_ptr = i//32
            ch_off = i%32
            ch_offptr = ch_off//2
            ch_offoff = ch_off%2
            for row in range(7):
                for col in range(2):
                    for col_i in range(4):
                        if col*4 + col_i < 7:
                            index = ch_ptr*img_height*img_width_ceil + row*img_width_ceil + col
                            tmp4 = DDR_all_p[index][col_i*16 + ch_offptr]
                            if ch_offoff == 1:
                                tmp4int = tmp4//16
                            else:
                                tmp4int = tmp4%16
                            tmp4_norm = tmp4int*2/15 - 1
                            conv13_hw[i][row][col*4 + col_i] = tmp4_norm
        avgpool_out = avgpool(conv13_hw)
        pred, logits = matmul(avgpool_out, fc_weight, fc_bias)
        print(pred)
        predicts.append(pred)
        if len(predicts) == num_img:
            break

# %%
from time import perf_counter
idle = FracNet.register_map.CTRL.AP_IDLE
FracNet.register_map.CTRL.AP_START = 0

mgr = Manager()

predicts = mgr.list()
np.set_printoptions(precision=3)

conv_out_q = mgr.Queue()

t = 0
correct = 0

img_height = 7
img_width = 7
img_width_ceil = 2

num_imgs = 1


p1 = Process(target=classifier, args=(fc_weight, fc_bias, conv_out_q, num_imgs))
p1.start()

for i in range(num_imgs):
    np.copyto(image_thermo, image_hw_all_file)
    idle = 0
    FracNet.register_map.CTRL.AP_START = 1
    
    ts = perf_counter()
    while idle == 0:
        idle = FracNet.register_map.CTRL.AP_IDLE
    tt = perf_counter()
    t += tt - ts
    conv_out_q.put(DDR_all)
#     print_ch = 0
# #     print(DDR_all[print_ch])
#     conv13_hw = np.ndarray((1024, 7, 7))
#     for i in range(1024):
#         ch_ptr = i//32
#         ch_off = i%32
#         ch_offptr = ch_off//2
#         ch_offoff = ch_off%2
#         for row in range(7):
#             for col in range(2):
#                 for col_i in range(4):
#                     if col*4 + col_i < 7:
#                         index = ch_ptr*img_height*img_width_ceil + row*img_width_ceil + col
#                         tmp4 = DDR_all[index][col_i*16 + ch_offptr]
#                         if ch_offoff == 1:
#                             tmp4int = tmp4//16
#                         else:
#                             tmp4int = tmp4%16
#                         tmp4_norm = tmp4int*2/15 - 1
#                         conv13_hw[i][row][col*4 + col_i] = tmp4_norm

#     print(conv13_hw[print_ch])
#     avgpool_out = avgpool(conv13_hw)
#     print(avgpool_out)
#     prediction, logits = matmul(avgpool_out, fc_weight, fc_bias)
#     print('Prediction: ', prediction)
# print(t/num_imgs)
p1.join()  
print(predicts)

# %%
DDR_all.shape
# Out:
# (64, 114, 114)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-68d4f1bcefa7> in <module>()
# ----> 1 import numba
#
# ModuleNotFoundError: No module named 'numba'

# %%
print(len(DDR_all[0][0][0]))
# Out:
# 64

# %%
## L1 has 8.55 ms
## Transactions have 30.75 ms
